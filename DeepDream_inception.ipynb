# %% [markdown]
# # Create a deep dream
#
# https://keras.io/examples/deep_dream/

# %%
import os
from PIL import Image
from keras.applications.vgg16 import VGG16
from keras.applications import inception_v3
import numpy as np
import keras.backend as K
from keras.models import Model
from keras.utils import plot_model
from keras.preprocessing.image import load_img, save_img, img_to_array
import scipy
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load the input

# %%
inputPic = "D:/Project/DeepLearning/DeepDream/Data/original/IMG_20170509_155330.jpg"

# %%
def preprocess_image(image_path):
    '''Load the picture; convert it as numpy array'''
    img = load_img(image_path)
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = inception_v3.preprocess_input(img)
    return img

def deprocess_image(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, x.shape[2], x.shape[3]))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((x.shape[1], x.shape[2], 3))
    x /= 2.
    x += 0.5
    x *= 255.
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
img = preprocess_image(inputPic)

# %% [markdown]
# ## Model creation

# %%
model = inception_v3.InceptionV3(weights='imagenet', include_top=False, input_shape=img[0].shape )
dream = model.input

# %%
K.set_learning_phase(0)

# %% [markdown]
# **Create 5 amplifications:**
# * features 0 : The values given by keras
# * features 1 Amplification of first layers' activation, and reduce other.
# * features 2 Amplification of middle layers activation
# * features 3 Amplified the layers in the end of inception
# * features 4 Amplified all the activations

# %%
# Parametres
step = 0.01  # Gradient ascent step size
num_octave = 5  # Number of scales at which to run gradient ascent
octave_scale = 1.4  # Size ratio between scales
iterations = 20  # Number of ascent steps per scale
max_loss = 10.

# %%
#Dictionnary of the layers to amplified + weights
settings = {'features0': {'mixed2': 0.2,'mixed3': 0.5,'mixed4': 2.,'mixed5': 1.5,},
           'features1': {'mixed2': 4.,'mixed3': 3.5,'mixed4': .02,'mixed5': .005,},
           'features2': {'mixed2': .1,'mixed3': 5.,'mixed4': 2.,'mixed5': .1,},
            'features3': {'mixed2': 0.02,'mixed3': 0.1,'mixed4': 3.,'mixed5': 5.,},
            'features4': {'mixed2': 3.,'mixed3': 3.,'mixed4': 3.,'mixed5': 3.,},
           }

# %%
#Create a dictionnary with coupple layer's name, layer's object
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
for key in settings.keys():

    #Loss function
    loss = K.variable(0.)
    for layer_name in settings[key]:

        if layer_name not in layer_dict:
            raise ValueError('Layer ' + layer_name + ' not found in model.')


        coeff = settings[key][layer_name] # Get the coefficient from setting dict for a layer
        x = layer_dict[layer_name].output # Get the activation values

        scaling = K.prod(K.cast(K.shape(x), 'float32')) # Number of neurons in the layer
        if K.image_data_format() == 'channels_first':
            loss = loss + coeff * K.sum(K.square(x[:, :, 2: -2, 2: -2])) / scaling
        else:
            #The loss is sum of MSE of activation value 
            loss = loss + coeff * K.sum(K.square(x[:, 2: -2, 2: -2, :])) / scaling

    #Gradient
    grads = K.gradients(loss, dream)[0]
    # Normalize gradients.
    grads /= K.maximum(K.mean(K.abs(grads)), K.epsilon())
    outputs = [loss, grads]
    fetch_loss_and_grads = K.function([dream], outputs)

    def eval_loss_and_grads(x):
        '''Loss and gradient evaluation'''
        outs = fetch_loss_and_grads([x])
        loss_value = outs[0]
        grad_values = outs[1]
        return loss_value, grad_values

    def resize_img(img, size):
        '''Return a zommed version of the image'''
        img = np.copy(img)
        if K.image_data_format() == 'channels_first':
            factors = (1, 1,
                       float(size[0]) / img.shape[2],
                       float(size[1]) / img.shape[3])
        else:
            factors = (1,
                       float(size[0]) / img.shape[1],
                       float(size[1]) / img.shape[2],
                       1)
        return scipy.ndimage.zoom(img, factors, order=1)


    def gradient_ascent(x, iterations, step, max_loss=None):
        ''''''
        for i in range(iterations):
            loss_value, grad_values = eval_loss_and_grads(x)
            if max_loss is not None and loss_value > max_loss:
                break
            print('..Loss value at', i, ':', loss_value)
            x += step * grad_values
        return x


    if K.image_data_format() == 'channels_first':
        original_shape = img.shape[2:]
    else:
        original_shape = img.shape[1:3]

    successive_shapes = [original_shape]

    for i in range(1, num_octave):
        shape = tuple([int(dim / (octave_scale ** i)) for dim in original_shape])
        successive_shapes.append(shape)

    successive_shapes = successive_shapes[::-1]
    original_img = np.copy(img)
    shrunk_original_img = resize_img(img, successive_shapes[0])

    for shape in successive_shapes:
        print('Processing image shape', shape)
        img = resize_img(img, shape)
        img = gradient_ascent(img,
                              iterations=iterations,
                              step=step,
                              max_loss=max_loss)
        upscaled_shrunk_original_img = resize_img(shrunk_original_img, shape)
        same_size_original = resize_img(original_img, shape)
        lost_detail = same_size_original - upscaled_shrunk_original_img

        img += lost_detail
        shrunk_original_img = resize_img(original_img, shape)


    save_img("D:/Project/DeepLearning/DeepDream/Output/inception/flower/res_" + key + '.png', deprocess_image(np.copy(img)))

    img = preprocess_image(inputPic)
# Out:
# Processing image shape (266, 149)
# ..Loss value at 0 : 0.68362355
# ..Loss value at 1 : 0.81318736
# ..Loss value at 2 : 1.1164751
# ..Loss value at 3 : 1.4358656
# ..Loss value at 4 : 1.7089396
# ..Loss value at 5 : 1.9051473
# ..Loss value at 6 : 2.125979
# ..Loss value at 7 : 2.3484793
# ..Loss value at 8 : 2.5651379
# ..Loss value at 9 : 2.7165856
# ..Loss value at 10 : 2.918583
# ..Loss value at 11 : 3.082869
# ..Loss value at 12 : 3.310677
# ..Loss value at 13 : 3.4231477
# ..Loss value at 14 : 3.6136048
# ..Loss value at 15 : 3.6865506
# ..Loss value at 16 : 3.895085
# ..Loss value at 17 : 4.0061727
# ..Loss value at 18 : 4.1812334
# ..Loss value at 19 : 4.2809973
# Processing image shape (373, 209)
# ..Loss value at 0 : 1.1967751
# ..Loss value at 1 : 1.7420886
# ..Loss value at 2 : 2.1521103
# ..Loss value at 3 : 2.4658298
# ..Loss value at 4 : 2.8205535
# ..Loss value at 5 : 3.1059904
# ..Loss value at 6 : 3.4135957
# ..Loss value at 7 : 3.7045114
# ..Loss value at 8 : 3.9644113
# ..Loss value at 9 : 4.239211
# ..Loss value at 10 : 4.494161
# ..Loss value at 11 : 4.716597
# ..Loss value at 12 : 4.933734
# ..Loss value at 13 : 5.1992745
# ..Loss value at 14 : 5.4044685
# ..Loss value at 15 : 5.6207685
# ..Loss value at 16 : 5.825863
# ..Loss value at 17 : 6.0265207
# ..Loss value at 18 : 6.2483644
# ..Loss value at 19 : 6.4373455
# Processing image shape (522, 293)
# ..Loss value at 0 : 1.3933182
# ..Loss value at 1 : 2.0641434
# ..Loss value at 2 : 2.597499
# ..Loss value at 3 : 3.0508504
# ..Loss value at 4 : 3.4809847
# ..Loss value at 5 : 3.8948793
# ..Loss value at 6 : 4.2632995
# ..Loss value at 7 : 4.6193676
# ..Loss value at 8 : 4.9627686
# ..Loss value at 9 : 5.291062
# ..Loss value at 10 : 5.607846
# ..Loss value at 11 : 5.911252
# ..Loss value at 12 : 6.210559
# ..Loss value at 13 : 6.494722
# ..Loss value at 14 : 6.7578835
# ..Loss value at 15 : 7.05826
# ..Loss value at 16 : 7.3142223
# ..Loss value at 17 : 7.57516
# ..Loss value at 18 : 7.8116446
# ..Loss value at 19 : 8.071972
# Processing image shape (731, 411)
# ..Loss value at 0 : 1.5297532
# ..Loss value at 1 : 2.2540233
# ..Loss value at 2 : 2.8771882
# ..Loss value at 3 : 3.4744356
# ..Loss value at 4 : 4.104528
# ..Loss value at 5 : 5.0033164
# ..Loss value at 6 : 5.8776393
# ..Loss value at 7 : 7.8331423
# Processing image shape (1024, 576)
# ..Loss value at 0 : 2.6801739
# ..Loss value at 1 : 5.438873
# Processing image shape (266, 149)
# ..Loss value at 0 : 2.6659043
# ..Loss value at 1 : 2.970112
# ..Loss value at 2 : 3.6818097
# ..Loss value at 3 : 4.3649545
# ..Loss value at 4 : 4.950226
# ..Loss value at 5 : 5.486269
# ..Loss value at 6 : 6.044528
# ..Loss value at 7 : 6.48689
# ..Loss value at 8 : 6.973481
# ..Loss value at 9 : 7.465163
# ..Loss value at 10 : 7.9149165
# ..Loss value at 11 : 8.361947
# ..Loss value at 12 : 8.832785
# ..Loss value at 13 : 9.200242
# ..Loss value at 14 : 9.571065
# ..Loss value at 15 : 9.980224
# Processing image shape (373, 209)
# ..Loss value at 0 : 4.071532
# ..Loss value at 1 : 5.5021234
# ..Loss value at 2 : 6.608314
# ..Loss value at 3 : 7.5480113
# ..Loss value at 4 : 8.425039
# ..Loss value at 5 : 9.152295
# ..Loss value at 6 : 9.936364
# Processing image shape (522, 293)
# ..Loss value at 0 : 4.291111
# ..Loss value at 1 : 5.6298256
# ..Loss value at 2 : 6.7730646
# ..Loss value at 3 : 7.815447
# ..Loss value at 4 : 8.789123
# ..Loss value at 5 : 9.69378
# Processing image shape (731, 411)
# ..Loss value at 0 : 4.480469
# ..Loss value at 1 : 5.8116193
# ..Loss value at 2 : 6.987057
# ..Loss value at 3 : 8.0466385
# ..Loss value at 4 : 9.065555
# ..Loss value at 5 : 9.9975195
# Processing image shape (1024, 576)
# ..Loss value at 0 : 4.745423
# ..Loss value at 1 : 6.172401
# ..Loss value at 2 : 7.3735533
# ..Loss value at 3 : 8.456398
# ..Loss value at 4 : 9.51795
# Processing image shape (266, 149)
# ..Loss value at 0 : 1.9404179
# ..Loss value at 1 : 2.1651828
# ..Loss value at 2 : 2.8720198
# ..Loss value at 3 : 3.5438178
# ..Loss value at 4 : 4.1930814
# ..Loss value at 5 : 4.9039497
# ..Loss value at 6 : 5.3885903
# ..Loss value at 7 : 5.938086
# ..Loss value at 8 : 6.476845
# ..Loss value at 9 : 7.0184884
# ..Loss value at 10 : 7.4408016
# ..Loss value at 11 : 7.982883
# ..Loss value at 12 : 8.576478
# ..Loss value at 13 : 8.942593
# ..Loss value at 14 : 9.621152
# Processing image shape (373, 209)
# ..Loss value at 0 : 3.4965432
# ..Loss value at 1 : 4.9994893
# ..Loss value at 2 : 6.236339
# ..Loss value at 3 : 7.313924
# ..Loss value at 4 : 8.378707
# ..Loss value at 5 : 9.372058
# Processing image shape (522, 293)
# ..Loss value at 0 : 3.877181
# ..Loss value at 1 : 5.3957725
# ..Loss value at 2 : 6.7919493
# ..Loss value at 3 : 8.064754
# ..Loss value at 4 : 9.385833
# Processing image shape (731, 411)
# ..Loss value at 0 : 4.429323
# ..Loss value at 1 : 6.3579264
# ..Loss value at 2 : 8.398445
# Processing image shape (1024, 576)
# ..Loss value at 0 : 4.9165063
# ..Loss value at 1 : 7.0795655
# ..Loss value at 2 : 9.550707
# Processing image shape (266, 149)
# ..Loss value at 0 : 1.0581878
# ..Loss value at 1 : 1.3601267
# ..Loss value at 2 : 1.9587977
# ..Loss value at 3 : 2.5682397
# ..Loss value at 4 : 3.0683746
# ..Loss value at 5 : 3.6337237
# ..Loss value at 6 : 4.112485
# ..Loss value at 7 : 4.5254054
# ..Loss value at 8 : 4.8657455
# ..Loss value at 9 : 5.2200575
# ..Loss value at 10 : 5.6816187
# ..Loss value at 11 : 5.9680033
# ..Loss value at 12 : 6.3107557
# ..Loss value at 13 : 6.685872
# ..Loss value at 14 : 6.92907
# ..Loss value at 15 : 7.4215126
# ..Loss value at 16 : 7.611701
# ..Loss value at 17 : 7.9786043
# ..Loss value at 18 : 8.169905
# ..Loss value at 19 : 8.545697
# Processing image shape (373, 209)
# ..Loss value at 0 : 1.947446
# ..Loss value at 1 : 2.9677882
# ..Loss value at 2 : 3.781199
# ..Loss value at 3 : 4.4097786
# ..Loss value at 4 : 5.0039597
# ..Loss value at 5 : 5.5282054
# ..Loss value at 6 : 6.1171494
# ..Loss value at 7 : 6.566058
# ..Loss value at 8 : 7.108658
# ..Loss value at 9 : 7.4956455
# ..Loss value at 10 : 7.9832573
# ..Loss value at 11 : 8.425753
# ..Loss value at 12 : 8.853614
# ..Loss value at 13 : 9.245228
# ..Loss value at 14 : 9.668989
# ..Loss value at 15 : 9.997807
# Processing image shape (522, 293)
# ..Loss value at 0 : 2.0798242
# ..Loss value at 1 : 3.1670938
# ..Loss value at 2 : 4.0486875
# ..Loss value at 3 : 4.7961483
# ..Loss value at 4 : 5.47623
# ..Loss value at 5 : 6.159441
# ..Loss value at 6 : 6.8115807
# ..Loss value at 7 : 7.4091663
# ..Loss value at 8 : 7.985898
# ..Loss value at 9 : 8.620115
# ..Loss value at 10 : 9.191776
# ..Loss value at 11 : 9.800734
# Processing image shape (731, 411)
# ..Loss value at 0 : 2.189565
# ..Loss value at 1 : 3.402391
# ..Loss value at 2 : 4.4983516
# ..Loss value at 3 : 5.61139
# ..Loss value at 4 : 7.0935163
# ..Loss value at 5 : 9.101007
# Processing image shape (1024, 576)
# ..Loss value at 0 : 4.1890182
# ..Loss value at 1 : 9.061344
# Processing image shape (266, 149)
# ..Loss value at 0 : 2.8818836
# ..Loss value at 1 : 3.2404976
# ..Loss value at 2 : 4.1212955
# ..Loss value at 3 : 4.9012704
# ..Loss value at 4 : 5.5489097
# ..Loss value at 5 : 6.1817884
# ..Loss value at 6 : 6.750028
# ..Loss value at 7 : 7.4308634
# ..Loss value at 8 : 7.9780827
# ..Loss value at 9 : 8.727788
# ..Loss value at 10 : 9.170265
# ..Loss value at 11 : 9.6533165
# Processing image shape (373, 209)
# ..Loss value at 0 : 4.3230968
# ..Loss value at 1 : 5.8392873
# ..Loss value at 2 : 7.0053997
# ..Loss value at 3 : 8.050976
# ..Loss value at 4 : 9.050836
# ..Loss value at 5 : 9.914355
# Processing image shape (522, 293)
# ..Loss value at 0 : 4.6163125
# ..Loss value at 1 : 6.102949
# ..Loss value at 2 : 7.3426676
# ..Loss value at 3 : 8.5384
# ..Loss value at 4 : 9.697738
# Processing image shape (731, 411)
# ..Loss value at 0 : 4.8722754
# ..Loss value at 1 : 6.4526753
# ..Loss value at 2 : 8.053506
# ..Loss value at 3 : 9.94944
# Processing image shape (1024, 576)
# ..Loss value at 0 : 5.6240115
# ..Loss value at 1 : 7.966385

# %%
img = [inputPic]
for i in settings.keys():
    img.append("D:/Project/DeepLearning/DeepDream/Output/inception/flower/res_{}.png".format(i))


img = list(map(lambda s: img_to_array(load_img(s)   ) , img )  )

r = img[0]
for i in img[1:]:
    r = np.concatenate([r,i], axis =1)

Image.fromarray(r.astype('uint8')).save("D:/Project/DeepLearning/DeepDream/Output/inception/flower/comparison.png")
